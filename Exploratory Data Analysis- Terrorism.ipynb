# %% [markdown]
# # Name: Anuja Shirke
# ## Task  2: Exploratory Data Analysis- Terrorism

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file_path="C:/Users/91897/Desktop/Desktop/Anuja/The Sparks Foundation/Global Terrorism - START data/globalterrorismdb_0718dist.csv"
mydata=pd.read_csv(file_path, encoding= "latin")

# %%
mydata.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
mydata.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
mydata1=mydata.dropna(axis=1, inplace=False)

# %%
mydata1.head(10)
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
# 5  197001010002   1970       1     1         0      217       United States
# 6  197001020001   1970       1     2         0      218             Uruguay
# 7  197001020002   1970       1     2         0      217       United States
# 8  197001020003   1970       1     2         0      217       United States
# 9  197001030001   1970       1     3         0      217       United States
#
#    region                   region_txt  vicinity  ...  \
# 0       2  Central America & Caribbean         0  ...
# ...

# %%
mydata1.tail(10)
# Out:
#              eventid  iyear  imonth  iday  extended  country  country_txt  \
# 181681  201712310016   2017      12    31         0      160  Philippines
# 181682  201712310017   2017      12    31         0       98        Italy
# 181683  201712310018   2017      12    31         0        4  Afghanistan
# 181684  201712310019   2017      12    31         0       92        India
# 181685  201712310020   2017      12    31         0        4  Afghanistan
# 181686  201712310022   2017      12    31         0      182      Somalia
# 181687  201712310029   2017      12    31         0      200        Syria
# 181688  201712310030   2017      12    31         0      160  Philippines
# 181689  201712310031   2017      12    31         0       92        India
# 181690  201712310032   2017      12    31         0      160  Philippines
#
#         region                  region_txt  vicinity  ...  \
# 181681       5              Southeast Asia         0  ...
# ...

# %%
mydata1.drop('extended', axis=1, inplace=True)
# Out:
# C:\Users\91897\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
mydata1.drop('country', axis=1, inplace=True)

# %%
mydata1.drop('region', axis=1, inplace=True)

# %%
mydata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   eventid          181691 non-null  int64
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   country_txt      181691 non-null  object
#  5   region_txt       181691 non-null  object
#  6   vicinity         181691 non-null  int64
#  7   crit1            181691 non-null  int64
#  8   crit2            181691 non-null  int64
#  9   crit3            181691 non-null  int64
#  10  success          181691 non-null  int64
#  11  suicide          181691 non-null  int64
#  12  attacktype1      181691 non-null  int64
#  13  attacktype1_txt  181691 non-null  object
#  14  targtype1        181691 non-null  int64
#  15  targtype1_txt    181691 non-null  object
# ...

# %%
mydata1.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'vicinity', 'crit1', 'crit2', 'crit3', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt', 'gname',
#        'individual', 'weaptype1', 'weaptype1_txt', 'property', 'dbsource',
#        'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
mydata1.duplicated().sum()
# Out:
# 0

# %%
mydata1.describe().T
# Out:
#                 count          mean           std           min           25%  \
# eventid      181691.0  2.002705e+11  1.325957e+09  1.970000e+11  1.991021e+11
# iyear        181691.0  2.002639e+03  1.325943e+01  1.970000e+03  1.991000e+03
# imonth       181691.0  6.467277e+00  3.388303e+00  0.000000e+00  4.000000e+00
# iday         181691.0  1.550564e+01  8.814045e+00  0.000000e+00  8.000000e+00
# vicinity     181691.0  6.829727e-02  2.845529e-01 -9.000000e+00  0.000000e+00
# crit1        181691.0  9.885300e-01  1.064825e-01  0.000000e+00  1.000000e+00
# crit2        181691.0  9.930927e-01  8.282305e-02  0.000000e+00  1.000000e+00
# crit3        181691.0  8.756680e-01  3.299608e-01  0.000000e+00  1.000000e+00
# success      181691.0  8.895983e-01  3.133907e-01  0.000000e+00  1.000000e+00
# suicide      181691.0  3.650704e-02  1.875486e-01  0.000000e+00  0.000000e+00
# attacktype1  181691.0  3.247547e+00  1.915772e+00  1.000000e+00  2.000000e+00
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(y=mydata1['attacktype1_txt'], hue=mydata1['targtype1_txt'], order=mydata['attacktype1_txt'].value_counts().index, palette="Set3");

# %% [markdown]
# The above plot explains about the attack type and target of terrorists. We can see Private Citizens & property and military has been attacked majority of times. The most popular weapon used by terrorists are bombing/explosion and armed assault.

# %%
plt.figure(figsize=(10,25))
plt.pie(mydata1['weaptype1_txt'].value_counts(), autopct="%1.1f%%");
#plt.tight_layout()
plt.legend(labels=mydata1['weaptype1_txt'].value_counts().index,loc='upper left', fontsize='small');

# %% [markdown]
# The pie plot talks about distribution of weapon type data. We can see explosives are used in more amount than others for terrorist attacks.

# %%
ct1=pd.crosstab(mydata['attacktype1_txt'], mydata['region_txt'])
ct1
# Out:
# region_txt                           Australasia & Oceania  \
# attacktype1_txt
# Armed Assault                                           51
# Assassination                                           36
# Bombing/Explosion                                       75
# Facility/Infrastructure Attack                          71
# Hijacking                                                3
# Hostage Taking (Barricade Incident)                      6
# Hostage Taking (Kidnapping)                             13
# Unarmed Assault                                         11
# Unknown                                                 16
#
# region_txt                           Central America & Caribbean  \
# attacktype1_txt
# Armed Assault                                               4361
# Assassination                                               1254
# Bombing/Explosion                                           3239
# Facility/Infrastructure Attack                               403
# ...

# %%
fig,ax=plt.subplots(figsize=(10,8));
ct1.plot.bar(stacked=True, ax=ax);

# %% [markdown]
# The bar chart shows South Asia and Middele East & North Africa has been attacked many times by using Armed Assault and Bombing/Explosions. Terrorist doesn't usually prefer Hostage taking, Unarmed assault and hijacking.

# %%
ax,fig=plt.subplots(figsize=(15,30))
sns.countplot(y=mydata['country_txt'], order=mydata['country_txt'].value_counts().index);

# %% [markdown]
# The above chart gives a count of terrorist attack across different countries. Here Iraq stands first following Pakistan and Afghanistan. Terrorist attacks are witnessed much in these countries.

# %%
sns.distplot(mydata1['iyear'], kde=True, hist=False);

# %% [markdown]
# The above plot shows increase in terrorist attacks. There's a drastic drop of number of terrorist attacks from 2015.

# %%
mydata1['gname'].value_counts()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Polish Skinheads                                        1
# Moslem Paramilitary Group                               1
# Paramilitary members                                    1
# Revolutionary Anarchist Armed Terrorist Movement        1
# Dissidents linked to Zanga                              1
# Name: gname, Length: 3537, dtype: int64

# %% [markdown]
# Here the value_counts() gives count of terrorist gang. Many attacks are done by unknown group following Taliban and ISIL.

# %%
g=sns.FacetGrid(mydata1, col="region_txt", col_wrap=3, height=3);
g=g.map(plt.scatter,"targtype1", "weaptype1");
g.add_legend();

# %%
mydata1[['weaptype1_txt','attacktype1_txt','targtype1_txt']]
# Out:
#        weaptype1_txt                 attacktype1_txt  \
# 0            Unknown                   Assassination
# 1            Unknown     Hostage Taking (Kidnapping)
# 2            Unknown                   Assassination
# 3         Explosives               Bombing/Explosion
# 4         Incendiary  Facility/Infrastructure Attack
# ...              ...                             ...
# 181686      Firearms                   Armed Assault
# 181687    Explosives               Bombing/Explosion
# 181688    Incendiary  Facility/Infrastructure Attack
# 181689    Explosives               Bombing/Explosion
# 181690    Explosives               Bombing/Explosion
#
#                       targtype1_txt
# 0       Private Citizens & Property
# 1           Government (Diplomatic)
# 2               Journalists & Media
# 3           Government (Diplomatic)
# 4           Government (Diplomatic)
# ...                             ...
# 181686                     Military
# ...

# %%
mydata1['attacktype1_txt']
# Out:
# 0                          Assassination
# 1            Hostage Taking (Kidnapping)
# 2                          Assassination
# 3                      Bombing/Explosion
# 4         Facility/Infrastructure Attack
#                        ...
# 181686                     Armed Assault
# 181687                 Bombing/Explosion
# 181688    Facility/Infrastructure Attack
# 181689                 Bombing/Explosion
# 181690                 Bombing/Explosion
# Name: attacktype1_txt, Length: 181691, dtype: object
